# %%
from bs4 import BeautifulSoup
import requests


page_to_scrape=requests.get("https://quotes.toscrape.com")
soup=BeautifulSoup(page_to_scrape.text,"html.parser")
quotes=soup.findAll("span",attrs={"class":"text"})
authors=soup.findAll("small",attrs={"class":"author"})
tags=soup.findAll("small",attrs={"class":"tag"})

for quote in quotes:
    print(quote.text)
for author in authors:
    print(author.text)
for tag in tags:
    print(tag.text)
# Out:
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
# “Try not to become a man of success. Rather become a man of value.”
# “It is better to be hated for what you are than to be loved for what you are not.”
# “I have not failed. I've just found 10,000 ways that won't work.”
# “A woman is like a tea bag; you never know how strong it is until it's in hot water.”
# “A day without sunshine is like, you know, night.”
# Albert Einstein
# J.K. Rowling
# Albert Einstein
# Jane Austen
# ...

# %%
from bs4 import BeautifulSoup
import requests

url="https://en.wikipedia.org/wiki/List_of_tallest_statues"
page=requests.get(url)
soup=BeautifulSoup(page.text, 'html')
#print(soup)
print(soup.findAll('table')[2])
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Statue
# </th>
# <th class="unsortable">Photo
# </th>
# <th>Depicts
# </th>
# <th>Location
# </th>
# <th>Country
# </th>
# <th>Height<br/>m (ft)
# </th>
# <th>Completed
# </th>
# <th>Destroyed
# </th>
# <th>Cause of destruction
# </th>
# <th class="unsortable">Notes
# </th>
# <th class="unsortable">Ref
# </th></tr>
# <tr>
# <td><a href="/wiki/Colossus_of_Rhodes" title="Colossus of Rhodes">Colossus of Rhodes</a>
# </td>
# ...

# %%
names=soup.findAll('table',class_='wikitable sortable')
statue_names=soup.findAll("span",attr={'class':'headerSort'})
print(names)
# Out:
# [<table class="wikitable sortable" style="margin:auto;">
# <tbody><tr>
# <th>Rank
# </th>
# <th>Country/region
# </th>
# <th>Number of<br/> statues
# </th></tr>
# <tr>
# <td align="center">1
# </td>
# <td>China
# </td>
# <td align="right">16
# </td></tr>
# <tr>
# <td align="center">2
# </td>
# <td>Japan
# </td>
# <td align="right">9
# </td></tr>
# <tr>
# <td align="center">3
# </td>
# <td>Thailand
# </td>
# <td align="right">8
# </td></tr>
# <tr>
# <td align="center">4
# </td>
# <td>India, Myanmar, Philippines, Taiwan, Vietnam
# </td>
# <td align="right">2
# </td></tr>
# <tr>
# <td align="center">9
# </td>
# <td>Indonesia, Mexico, Russia, Ukraine, France, Senegal
# </td>
# <td align="right">1
# </td></tr>
# <tr>
# <th colspan="2"><b>(Total)</b>
# </th>
# <td align="right"><b>47</b>
# </td></tr>
# </tbody></table>, <table class="wikitable sortable">
# <tbody><tr>
# <th>Statue
# </th>
# <th class="unsortable">Photo
# </th>
# <th>Depicts
# </th>
# <th>Location
# </th>
# <th>Country
# ...

# %%
print(soup.title)
# Out:
# <title>List of tallest statues - Wikipedia</title>

# %%
print(soup.title.name)
# Out:
# title

# %%
print(soup.title.string)
# Out:
# List of tallest statues - Wikipedia

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# #bodyContent
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Main_Page
# /wiki/Special:Search
# /w/index.php?title=Special:CreateAccount&returnto=List+of+tallest+statues
# /w/index.php?title=Special:UserLogin&returnto=List+of+tallest+statues
# /w/index.php?title=Special:CreateAccount&returnto=List+of+tallest+statues
# /w/index.php?title=Special:UserLogin&returnto=List+of+tallest+statues
# /wiki/Help:Introduction
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# #
# #Existing
# #By_country/region
# #Destroyed
# #Proposed_or_under_construction
# #See_also
# ...

# %%
print(soup.find_all('a'))
# Out:
# [<a class="mw-jump-link" href="#bodyContent">Jump to content</a>, <a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]"><span>Main page</span></a>, <a href="/wiki/Wikipedia:Contents" title="Guides to browsing Wikipedia"><span>Contents</span></a>, <a href="/wiki/Portal:Current_events" title="Articles related to current events"><span>Current events</span></a>, <a accesskey="x" href="/wiki/Special:Random" title="Visit a randomly selected article [x]"><span>Random article</span></a>, <a href="/wiki/Wikipedia:About" title="Learn about Wikipedia and how it works"><span>About Wikipedia</span></a>, <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia"><span>Contact us</span></a>, <a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us by donating to the Wikimedia Foundation"><span>Donate</span></a>, <a href="/wiki
# ...
